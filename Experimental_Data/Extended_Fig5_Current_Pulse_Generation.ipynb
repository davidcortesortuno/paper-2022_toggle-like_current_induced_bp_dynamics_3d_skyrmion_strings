# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as c
import scipy.fftpack as fft
import scipy.ndimage as ndi
import scipy as sp
from PIL import Image

def px_remove(array, x, y):
    temp = array
    temp[y,x]=(temp[y+1,x]+temp[y-1,x]+temp[y,x+1]+temp[y,x-1])/4
    return temp

def px_remove_edge(array, x, y):
    temp = array
    temp[y,x]=(temp[y+1,x]+temp[y-1,x]+temp[y,x-1])/3
    return temp

# %% [markdown]
# # Load Data

# %%
# %matplotlib notebook

fields = ['0','10','20','30','40','50','60','70','80']

Gen_list = []

for i in np.arange(0,len(fields),1):
    pos_im = Image.open("STXM_Data/Pulse_Different_IP_Fields/TIF_Data/Pulse_"+fields[i]+"mT_pos.tif")
    neg_im = Image.open("STXM_Data/Pulse_Different_IP_Fields/TIF_Data/Pulse_"+fields[i]+"mT_neg.tif")
    pos =np.array(pos_im)
    neg =np.array(neg_im)

    pos = np.rot90(pos)
    neg = np.rot90(neg)

    final = pos/neg
    final = np.fliplr(final)
    Gen_list.append(final)

# %%
Gen_final_list = []
temp1 = px_remove(Gen_list[0], 148, 24)
#temp2 = px_remove(temp1, 68, 23)
Gen_final_list.append(temp1)

temp1 = px_remove(Gen_list[1], 177, 19)
temp2 = px_remove(temp1, 134, 15)
Gen_final_list.append(temp2)

temp1 = px_remove(Gen_list[2], 156, 20)
temp2 = px_remove(temp1, 39, 23)
Gen_final_list.append(temp2)

temp1 = px_remove(Gen_list[3], 49, 24)
#temp2 = px_remove(temp1, 39, 23)
Gen_final_list.append(temp1)

temp1 = px_remove(Gen_list[4], 93, 12)
#temp2 = px_remove(temp1, 39, 23)
Gen_final_list.append(temp1)

temp1 = px_remove(Gen_list[7], 59, 7)
temp2 = px_remove(temp1, 72, 34)
Gen_final_list.append(temp1)

# %%
# %matplotlib notebook
plt.figure(figsize=(5,3))

ax1=plt.subplot2grid((1,1),(0,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[8][:,:],cmap='plasma')
plt.xticks([])
plt.yticks([])

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
plt.figure(figsize=(4,8))

# 20 mT #
ax1=plt.subplot2grid((9,1),(0,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[0][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.9,vmax=1.1)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
# 40 mT #
ax1=plt.subplot2grid((9,1),(1,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[1][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.1)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 50 mT #
ax1=plt.subplot2grid((9,1),(2,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[2][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.92,vmax=1.08)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 55 mT #
ax1=plt.subplot2grid((9,1),(3,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[3][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.92,vmax=1.08)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
# 60 mT #
ax1=plt.subplot2grid((9,1),(4,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[4][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.08)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 65 mT #
ax1=plt.subplot2grid((9,1),(5,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[5][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.06)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
# 70 mT #
ax1=plt.subplot2grid((9,1),(6,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[6][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.94,vmax=1.08)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
# 75 mT #
ax1=plt.subplot2grid((9,1),(7,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[7][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.96,vmax=1.06)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 80 mT #
ax1=plt.subplot2grid((9,1),(8,0), rowspan=1,colspan=1)
plt.imshow(Gen_list[8][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.96,vmax=1.06)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
plt.tight_layout()

plt.savefig('Figure_Panels/Extended_Data_Pulse_Diff_Field.png',dpi=300)
# Out:
# <div id='f57aa518-34b2-41ab-8624-b862eb753c72'></div>

# %%
# %matplotlib notebook

fields = ['0','10','20','30','40','50']

Reset_list = []

for i in np.arange(0,len(fields),1):
    pos_im = Image.open("Fig_Pulse_Generate/Reset_"+fields[i]+"mT_pos.tif")
    neg_im = Image.open("Fig_Pulse_Generate/Reset_"+fields[i]+"mT_neg.tif")
    pos =np.array(pos_im)
    neg =np.array(neg_im)

    pos = np.rot90(pos)
    neg = np.rot90(neg)

    final = pos/neg
    final = np.fliplr(final)
    Reset_list.append(final)

# %%
Reset_final_list = []
temp1 = px_remove(Reset_list[4], 41, 19)
temp2 = px_remove(temp1, 41, 18)
temp3 = px_remove(temp1, 125, 22)

Reset_final_list.append(temp3)

temp1 = px_remove(Reset_list[5], 59, 10)
temp2 = px_remove(temp1, 74, 22)

Reset_final_list.append(temp2)

# %%
# %matplotlib notebook
plt.figure(figsize=(5,3))

ax1=plt.subplot2grid((1,1),(0,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[5][:,:],cmap='plasma')
plt.xticks([])
plt.yticks([])

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
plt.figure(figsize=(4,8))

# 20 mT #
ax1=plt.subplot2grid((9,1),(0,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[0][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.9,vmax=1.1)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
# 40 mT #
ax1=plt.subplot2grid((9,1),(1,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[1][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.1)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 50 mT #
ax1=plt.subplot2grid((9,1),(2,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[2][4:-4,25:-8],cmap='plasma',interpolation='hamming',vmin=0.92,vmax=1.08)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 55 mT #
ax1=plt.subplot2grid((9,1),(3,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[3][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.92,vmax=1.08)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
# 60 mT #
ax1=plt.subplot2grid((9,1),(4,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[4][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.08)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 65 mT #
ax1=plt.subplot2grid((9,1),(5,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[5][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.06)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 65 mT #
ax1=plt.subplot2grid((9,1),(6,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[5][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.06)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 65 mT #
ax1=plt.subplot2grid((9,1),(7,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[5][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.06)
plt.xticks([])
plt.yticks([])
#plt.colorbar()

# 65 mT #
ax1=plt.subplot2grid((9,1),(8,0), rowspan=1,colspan=1)
plt.imshow(Reset_list[5][3:-5,25:-8],cmap='plasma',interpolation='hamming',vmin=0.93,vmax=1.06)
plt.xticks([])
plt.yticks([])
#plt.colorbar()
 
plt.tight_layout()

plt.savefig('Reset_Diff_Field.png',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="400">
