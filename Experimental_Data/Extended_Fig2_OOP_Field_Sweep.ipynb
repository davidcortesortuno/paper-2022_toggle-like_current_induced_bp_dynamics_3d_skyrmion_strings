# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as c
import scipy.fftpack as fft
import scipy.ndimage as ndi
import scipy as sp
from PIL import Image

def px_remove(array, x, y):
    temp = array
    temp[y,x]=(temp[y+1,x]+temp[y-1,x]+temp[y,x+1]+temp[y,x-1])/4
    return temp

def px_remove_edge(array, x, y):
    temp = array
    temp[y,x]=(temp[y+1,x]+temp[y-1,x]+temp[y,x-1])/3
    return temp

# %% [markdown]
# # Load Data

# %%
# %matplotlib notebook

fields = ['n250','n200','n150','n100','n75','n50','n25','p0','p25','p50','p75','p100','p150','p200','p250',]

OOP_list = []

for i in np.arange(0,len(fields),1):
    pos_im = Image.open("STXM_Data/OOP_Field_Sweep/TIF_Data/OOP_"+fields[i]+"mT_pos.tif")
    neg_im = Image.open("STXM_Data/OOP_Field_Sweep/TIF_Data/OOP_"+fields[i]+"mT_neg.tif")
    pos =np.array(pos_im)
    neg =np.array(neg_im)

    pos = np.rot90(pos)
    neg = np.rot90(neg)

    final = pos/neg
    final = np.fliplr(final)
    OOP_list.append(final)

# %%
OOP_final_list = []
# -250 mT #
temp1 = px_remove(OOP_list[0], 170, 19)
temp2 = px_remove(temp1, 170, 20)
OOP_final_list.append(temp2)

# -200 mT #
OOP_final_list.append(OOP_list[1])

# -150 mT #
temp1 = px_remove(OOP_list[2], 26, 21)
OOP_final_list.append(temp1)

# -100 mT #
OOP_final_list.append(OOP_list[3])

# -75 mT #
OOP_final_list.append(OOP_list[4])

# -50 mT #
temp1 = px_remove(OOP_list[5], 100, 7)
OOP_final_list.append(temp1)

# -25 mT #
OOP_final_list.append(OOP_list[6])

# 0 mT #
OOP_final_list.append(OOP_list[7])

# 25 mT #
temp1 = px_remove(OOP_list[8], 139, 22)
OOP_final_list.append(temp1)

# 50 mT #
OOP_final_list.append(OOP_list[9])

# 75 mT #
temp1 = px_remove(OOP_list[10], 102, 29)
OOP_final_list.append(temp1)

# 100 mT #
temp1 = px_remove(OOP_list[11], 66, 8)
temp2 = px_remove(temp1, 99, 9)
OOP_final_list.append(temp2)

# 150 mT #
OOP_final_list.append(OOP_list[12])

# 200 mT #
OOP_final_list.append(OOP_list[13])

# 250 mT #
OOP_final_list.append(OOP_list[14])

# %%
plt.figure(figsize=(8,3))

ax1=plt.subplot2grid((1,1),(0,0), rowspan=1,colspan=1)
plt.imshow(OOP_list[1],cmap='plasma')
plt.xticks([])
plt.yticks([])

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure(figsize=(8,7.5))

# -250 mT #
ax1=plt.subplot2grid((8,2),(0,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[0][4:-4,20:-13],cmap='plasma',vmin=1.01)
plt.xticks([])
plt.yticks([])
 
# -200 mT #
ax1=plt.subplot2grid((8,2),(1,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[1][3:-5,20:-13],cmap='plasma',vmin=1.01,vmax=1.19)
plt.xticks([])
plt.yticks([])
 
# -150 mT #
ax1=plt.subplot2grid((8,2),(2,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[2][3:-5,24:-9],cmap='plasma',vmin=1.02,vmax=1.15)
plt.xticks([])
plt.yticks([])
 
# -100 mT #
ax1=plt.subplot2grid((8,2),(3,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[3][2:-6,24:-9],cmap='plasma',vmin=0.99,vmax=1.12,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# -75 mT #
ax1=plt.subplot2grid((8,2),(4,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[4][2:-6,24:-9],cmap='plasma',vmin=0.95,vmax=1.12,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# -50 mT #
ax1=plt.subplot2grid((8,2),(5,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[5][2:-6,24:-9],cmap='plasma',vmin=0.94,vmax=1.09,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# -25 mT #
ax1=plt.subplot2grid((8,2),(6,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[6][2:-6,24:-9],cmap='plasma',vmin=0.94,vmax=1.08,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 0 mT #
ax1=plt.subplot2grid((8,2),(7,0), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[7][3:-5,24:-9],cmap='plasma',vmin=0.95,vmax=1.07,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 25 mT #
ax1=plt.subplot2grid((8,2),(0,1), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[8][3:-5,26:-7],cmap='plasma',vmin=0.93,vmax=1.06,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 50 mT #
ax1=plt.subplot2grid((8,2),(1,1), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[9][3:-5,28:-5],cmap='plasma',vmin=0.92,vmax=1.06,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 75 mT #
ax1=plt.subplot2grid((8,2),(2,1), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[10][4:-4,28:-5],cmap='plasma',vmin=0.9,vmax=1.02,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 100 mT #
ax1=plt.subplot2grid((8,2),(3,1), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[11][5:-3,26:-7],cmap='plasma',vmin=0.87,vmax=1.02,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 150 mT #
ax1=plt.subplot2grid((8,2),(4,1), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[12][5:-3,26:-7],cmap='plasma',vmin=0.87,vmax=0.97,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 200 mT #
ax1=plt.subplot2grid((8,2),(5,1), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[13][5:-3,26:-7],cmap='plasma',vmin=0.85,vmax=0.96,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
# 250 mT #
ax1=plt.subplot2grid((8,2),(6,1), rowspan=1,colspan=1)
plt.imshow(OOP_final_list[14][5:-3,26:-7],cmap='plasma',vmin=0.85,vmax=0.96,interpolation='hamming')
plt.xticks([])
plt.yticks([])
 
plt.tight_layout()

plt.savefig('Figure_Panels/Extended_Data_OOP_sweep.png',dpi=300)
# Out:
# <img src="data:image/png;base64,..." width="800">
